# %% [markdown]
# Remark by Cecilia Ulmke (June 15th, 2023): this Jupyter-Notebook is the original code by Amin Moussaid. For the final report of "Spundsteif" I have translated it into English and cleaned it up a little, see '`01_Werkhofversuche_Dehnmessstreifen.ipynb`'.

# %% [markdown]
# Exploitation des mesures de déformations
# ---

# %% [markdown]
# Structure de la base de données :
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **x** , **y** - *float* , *float* : Position du capteur dans la section
# *   **num_dms** - *int* : Numéro du capteur
# *   **serr_long** - *float* : Longueur de la perturbation de la serrure en tête (0.3 à 15m)
# *   **serr_type** - *str* : Type de perturbation soudée ou collée ('sch' ou 'klebt')
# *   **eps** - *float* : Valeur mesurée de la déformation
# *   **force** - *float* : Force appliquée pendant l'essai
# *   **essai** - *str* : Nom de l'essai
# *   **charg** - *bool* : 1 ou 0 représente respectivement la phase de chargement ou de déchargement

# %% [markdown]
# **Importation des data**

# %% [markdown]
# Répertoire :
#
# `P:\AHB\FE\02_PT\80_SI\81_GNE\81FE-010202-K-01_innosuisse_Entwicklung eines neuen Spundwandsystems\AP1\Werkhof\Ergebnisse\Reihe 2`
#
# Fichier :
# `DMS_vdata.csv`

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-74674261-59c1-431f-abb0-9bd0cd9724c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74674261-59c1-431f-abb0-9bd0cd9724c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DMS_vdata.csv to DMS_vdata.csv

# %% [markdown]
# **Améliorations possibles :**
#
# *  Possibilité de tracer plusieurs chargements sur le même graphique 3D.
# *   Ajouter quelques fonctions de traitement de la df.
# *   Ajouter des garde-fous : assert, conditions d'entrées, etc.
# *   Ajouter une df des données géométriques (x, y, pos_dms, num_pal), puis retrouver la df par jointure sur num_dms

# %% [markdown]
# # Initialisation

# %% [markdown]
# *Importation des bibliothèques*

# %%
import plotly.express as px
import plotly.graph_objects as go


from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd

# %%
#Creation de la base de données
import io
def reset_df():
  df = pd.read_csv(io.BytesIO(data_to_load['DMS_vdata.csv']), sep=';')
  return df

# %%
df = reset_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-926b3c2bd2f3> in <cell line: 1>()
# ----> 1 df = reset_df()
#
# <ipython-input-2-6eb553f32a33> in reset_df()
#       2 import io
#       3 def reset_df():
# ----> 4   df = pd.read_csv(io.BytesIO(data_to_load['DMS_vdata.csv']), sep=';')
#       5   return df
#
# NameError: name 'data_to_load' is not defined

# %% [markdown]
# # Fonctions de traitement de la base de données

# %%
def projection_chargement(serr_long, serr_type, force, charg):
  #Renvoie la projection relatif à un chargement
  return df.loc[(df['force'] == force) & (df['serr_type'] == serr_type) &
                (df['serr_long'] == serr_long) & (df['charg'] == charg)]

def _projection_chargement(serr_long, serr_type, force, charg):
  """
  Fonction projection pour une df mutliindex
  """
  return df.loc[(serr_type, serr_long, charg, force), :]

# %%
def add_pos_dms(df):
  """
  Ajoute à la df une colonne qui donne la position des capteurs
  et num palplanche
  """
  position_dictionary = {1:1, 5:2, 6:3 , 2:4, 7:5, 3:6, 4:7, 8:8}
  df['pos_dms'] = df['num_dms'].map(position_dictionary)
  df['indice_pal'] = np.where(df['pos_dms'] <= 4, 1, 2)
  return df

# %%
def _multi_index(df):
  #Comment la faire pour qu'elle ne modifie pas la df ?
  """
  Renvoie la df modifiée sous une structure multiindex
  """
  df.set_index(['serr_type', 'serr_long', 'charg', 'force'], inplace=True)
  df.sort_index(inplace=True)

# %%
def deformations_elastiques(df):
  """
  Renvoie df modifiée pour ne considérer que les déformations plastiques

  Pour ce faire on se propose de retirer a chaque valeur expérimentale
  la valeur des déformations mesurée au début de l'essai


  Plan :
  - On parcourt la df, pour chaque valeur de essai, on retire la valeurs
  eps du 1er chargement

  """
  serr_long = df['serr_long']
  serr_type = df['serr_type']
  serr = list(zip(serr_long, serr_type))
  serr = list(set(serr))

  for serr_long, serr_type in serr:
    force_min = df.loc[(df['serr_long'] == serr_long) &
                       (df['serr_type'] == serr_type) &
                       (df['charg'] == 1)]['force'].min()

    #Etat initial
    df_etat_initial = df.loc[(df['serr_long'] == serr_long) &
                             (df['serr_type'] == serr_type) &
                             (df['force'] == force_min)
                             & (df['charg'] == 1)]

    df_etat_initial.sort_values('num_dms')
    eps_initial = list(df_etat_initial['eps'])

    forces = df.loc[(df['serr_long'] == serr_long) &
                    (df['serr_type'] == serr_type)]['force']
    charges = df.loc[(df['serr_long'] == serr_long) &
                     (df['serr_type'] == serr_type)]['charg']
    forces_charges = list(zip(forces, charges))
    forces_charges = list(set(forces_charges))

    for force, charg in forces_charges:
      #Etat dans le temps sous la force 'force'
      df_temps = df.loc[(df.serr_long == serr_long) &
                        (df.serr_type == serr_type) &
                        (df.force == force) &
                        (df.charg == charg)]
      df_temps.sort_values('num_dms')
      eps_temps = list(df_temps['eps'])

      for i in range(len(eps_temps)):
        df.loc[(df.serr_long == serr_long) &
               (df.serr_type == serr_type) &
               (df.force == force) &
               (df.charg == charg) &
               (df.num_dms == i+1), 'new_eps'] \
             = eps_temps[i] - eps_initial[i]
  return df

# %% [markdown]
# Traitement df

# %%
df = reset_df()
df = deformations_elastiques(df)
add_pos_dms(df)
# Out:
#        x   y  num_dms  serr_long  ... charg  new_eps  pos_dms indice_pal
# 0   -600  22        1        0.3  ...     1      0.0        1          1
# 1   -600  22        1        0.3  ...     1    262.0        1          1
# 2   -600  22        1        0.3  ...     1    735.0        1          1
# 3   -600  22        1        0.3  ...     1   1305.0        1          1
# 4   -600  22        1        0.3  ...     0    830.0        1          1
# ..   ...  ..      ...        ...  ...   ...      ...      ...        ...
# 483  600 -22        8       15.0  ...     1   -177.0        8          2
# 484  600 -22        8       15.0  ...     1   -430.0        8          2
# 485  600 -22        8       15.0  ...     1   -783.0        8          2
# 486  600 -22        8       15.0  ...     1  -1028.0        8          2
# 487  600 -22        8       15.0  ...     0   -972.0        8          2
#
# [488 rows x 12 columns]

# %% [markdown]
# # Représentation des résultats expérimentaux

# %% [markdown]
# Fonctions
# ---

# %%
def representation_points3D(serr_long, serr_type, force, charg):

  """
  Plot 3D des valeurs des déformations mesurées dans l'espace (x, y, eps)
  """

  df_char = projection_chargement(serr_long, serr_type, force, charg)

  fig = px.scatter_3d(
      df_char, x='x', y='y', z='eps',
      color='indice_pal'
      )

  fig.update_layout(
      title_text='Valeurs mesurées des déformations',
      height=800,
      width=800
      )

  fig.update_traces(marker_symbol='x', marker_size=5)
  fig.show()

# %%
def representation_droite3D(serr_long, serr_type, force, charg):

  """
  Plot 3D par portions de droites des valeurs de déformations
  mesurées dans l'espace (x, y, eps)
  """

  #Extraction des données du chargement
  df_char = projection_chargement(serr_long, serr_type, force, charg)
  df_char = df_char.sort_values('pos_dms')

  fig = px.line_3d(df_char, x="x", y="y", z="eps",
                   color='indice_pal'
                   )

  fig.update_layout(
    title_text='Représentation par des sections de droites',
    height=800,
    width=800
  )

  #Ajouter le profil de la palplanche /
  #Pb = tracer deuxième jeu de données sur le même graph
  #fig.add_trace() ?

  fig.show()

# %% [markdown]
# Représentations 3D
# ---

# %%
#Arguments : representation_droite(serr_long, serr_type, force, charg)
#--> Caractérise entièrement un chargement
representation_points3D(0.3, 'sch', 22, 1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="834c2376-32e2-4e96-8bc2-1435404096fd" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("834c2376-32e2-4e96-8bc2-1435404096fd")) {
#                     Plotly.newPlot(
#                         '834c2376-32e2-4e96-8bc2-1435404096fd',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}<br>eps=%{z}<br>indice_pal=%{marker.color}", "legendgroup": "", "marker": {"color": [1, 1, 2, 2, 1, 1, 2, 2], "coloraxis": "coloraxis", "size": 5, "symbol": "x"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": [-600, 0, 150, 450, -450, -150, 0, 600], "y": [22, 22, 225, 225, -225, -225, -22, -22], "z": [262, 300, 195, 142, -152, -144, -331, -300]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "indice_pal"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 800, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "x"}}, "yaxis": {"title": {"text": "y"}}, "zaxis": {"title": {"text": "eps"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"o ...

# %%
representation_droite3D(0.3, 'sch', 22, 1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3beec3a-4ce8-48fa-afb2-7c33098f3bf5" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3beec3a-4ce8-48fa-afb2-7c33098f3bf5")) {
#                     Plotly.newPlot(
#                         'd3beec3a-4ce8-48fa-afb2-7c33098f3bf5',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "indice_pal=1<br>x=%{x}<br>y=%{y}<br>eps=%{z}", "legendgroup": "indice_pal=1", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "indice_pal=1", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-600, -450, -150, 0], "y": [22, -225, -225, 22], "z": [262, -152, -144, 300]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "indice_pal=2<br>x=%{x}<br>y=%{y}<br>eps=%{z}", "legendgroup": "indice_pal=2", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "indice_pal=2", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [0, 150, 450, 600], "y": [-22, 225, 225, -22], "z": [-331, 195, 142, -300]}],
#                         {"height": 800, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "x"}}, "yaxis": {"title": {"text": "y"}}, "zaxis": {"title": {"text": "eps"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"ma ...

# %% [markdown]
# # Evaluation du comportement local de la palplanche

# %% [markdown]
# *Objectif : Quantifier le comportement des palplanches localement*
#
# Pour ce faire, on se propose de retrouver numériquement la position de l'axe neutre.

# %% [markdown]
# *Remarque : DB = DoubleBohlen & 2EB = 2 Einzelbohlen*
#
# *Les fonctions peuvent fonctionner avec des dataframe multiindex. Seule la fonction de projection d'un chargement doit être modifiée.*

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# ### *Fonctions d'interpolation*

# %%
def interpolation_2EB(df_char):

  """
  A partir d'une df de chargement (8 entrées) on interpole les données
  selon le modèle des 2EB

  Renvoie une liste de taille 2, contenant les 2 4-uplets contenant les
  coef des régressions linéaires
  """

  assert len(df_char) == 8
  assert type(df_char) is pd.core.frame.DataFrame

  sortie = []
  indices_pal = df_char.indice_pal.unique()
  indices_pal.sort()

  for i in indices_pal:
    # Données dans la palplanche i
    df_pal = df_char.loc[df_char['indice_pal'] == i]
    # Vecteur position palplanche i
    X = np.transpose(np.array([df_pal['x'] , df_pal['y']]))
    y = df_pal['eps']

    reg = LinearRegression().fit(X,y)
    R = reg.score(X,y)

    sortie.append((reg.coef_[0], reg.coef_[1], reg.intercept_, R))

  return sortie

# %%
def interpolation_2EB_elastique(df_char):

  """
  A partir d'une df de chargement (8 entrées) on interpole les données
  selon le modèle des 2EB

  Renvoie une liste de taille 2, contenant les 2 4-uplets contenant les
  coef des régressions linéaires
  """

  assert len(df_char) == 8
  assert type(df_char) is pd.core.frame.DataFrame

  sortie = []
  indices_pal = df_char.indice_pal.unique()
  indices_pal.sort()

  for i in indices_pal:
    # Données dans la palplanche i
    df_pal = df_char.loc[df_char['indice_pal'] == i]
    # Vecteur position palplanche i
    X = np.transpose(np.array([df_pal['x'] , df_pal['y']]))
    y = df_pal['new_eps']

    reg = LinearRegression().fit(X,y)
    R = reg.score(X,y)

    sortie.append((reg.coef_[0], reg.coef_[1], reg.intercept_, R))

  return sortie

# %%
def _interpolation_DB(df_char):

  """
  A partir d'une df de chargement (8 entrées) on interpole les données selon le
  modèle des DB
  """

  assert len(df_char) <= 8, \
    'Interpolation possible uniquement pour des données d un chargement'
    #On laisse valable le cas ou on aurait moins de mesures
  assert type(df_char) is pd.core.frame.DataFrame

  X = np.transpose(np.array([df_char['x'] , df_char['y']]))  #Vecteur position
  y = df_char['eps']

  reg = LinearRegression().fit(X, y)
  R = reg.score(X,y)

  sortie = (reg.coef_[0], reg.coef_[1] , reg.intercept_, R)

  return sortie

# %%
def _interpolation_chargement(df_char):

  """
  Renvoie les coefs du modèle le plus adapté à la distribution des déformations
  """

  if len(df_char) != 8:
    print("Erreur : Interpolation uniquement pour des données de chargement")
    return False

  #Calcul des coef des 2 modèles
  coef_DB = _interpolation_DB(df_char)
  coef_2EB = interpolation_2EB(df_char)

  if coef_DB[3] < 0.9:
    return coef_2EB
  elif coef_DB[3] >= 0.9:
    return coef_DB

# %% [markdown]
# ### *Représentation graphique*

# %%
def axe_neutre(c, x_min, x_max):
  """
  Construit 3 listes pour représenter l'axe neutre d'une interpolation
  dans l'espace (x, y, eps)
  """

  assert type(c) is tuple, 'Fonction qui trace l axe neutre a' + \
                                'partir des coef d une regression linéaire'
  assert x_max > x_min, 'Vérifier les bornes du dessin'

  if c[1] == 0:
    return [], [], []

  x = np.linspace(x_min, x_max, 10)
  y = - 1 / c[1] * (c[0] * x + c[2])
  z = np.zeros(10)

  return x, y, z

# %%
# df_exemple = projection_chargement(15, 'klebt', 29, 1)
# c_exemple = _interpolation_DB(df_exemple)

# # ici vérifier que la fonction fonctionne bien pour df exemple
# assert axe_neutre(c_exemple) == x_a_trouver, y_a_trouver, O
# # De cette façon, tu es sûr que ta fonction axe_neutre est tjrs juste, y compris
# # quand tu la modifie

# %%
def representation_2EB(coef_reg, df_char):
  assert type(coef_reg) is list, 'Entrée doit être liste'
  assert len(coef_reg) == 2, 'Vérifier le modèle utilisé (DB ou 2EB)'

  X = []
  Y = []
  Z = []

  axe_n = []

  #Permet de choisir la zone de dessin des objets pour chaque palplanche
  X_SIZE = [[-700,100] , [-100,700]]
  Y_SIZE = [[-300,100] , [-100,300]]

  #Construction des données pour chacune des palplanches
  for i in [0,1]:
    c = coef_reg[i]
    print(c)
    x = np.linspace(X_SIZE[i][0], X_SIZE[i][1], 10)
    y = np.linspace(Y_SIZE[i][0], Y_SIZE[i][1], 10)
    xGrid, yGrid = np.meshgrid(x, y)
    z = c[0]*xGrid + c[1]*yGrid + c[2]

    axe_n.append(axe_neutre(c, X_SIZE[i][0], X_SIZE[i][1]))
    X.append(xGrid)
    Y.append(yGrid)
    Z.append(z)

  eps_min = min(np.amin(Z[0]) , np.amin(Z[1]))
  eps_max = max(np.amax(Z[0]) , np.amax(Z[1]))

  df_char = df_char.sort_values('pos_dms')

  fig = go.Figure(data=[
      #Tracé du plan des def de la palplanche 1
      go.Surface(x=X[0], y=Y[0], z=Z[0],
                 name='Interpolation - Spundbohle 1',
                 opacity = 0.8,
                 colorbar_x=1, colorbar_title='Spundbohle 1',
                 colorbar_thickness=20, colorbar_len=0.5,
                 autocolorscale=False,
                 colorscale=[[0, 'rgb(7,64,80)'],
                             [0.5, 'rgb(255,255,255)'],
                             [1, 'rgb(154,205,50)']],
                 cmin=eps_min, cmax=eps_max, cmid=0
                 ),
      #Tracé de l'axe neutre de la palplanche 1
      go.Scatter3d(x=axe_n[0][0], y=axe_n[0][1], z=axe_n[0][2],
                   name='Neutral Achse - Spundbohle 1',
                   mode='lines', line=dict(color='rgb(255,127,80)', width=3,
                                           dash="longdash")
                   ),
      #Tracé du plan des def de la palplanche 2
      go.Surface(x=X[1], y=Y[1], z=Z[1],
                 name='Interpolation - Spundbohle 2',
                 opacity = 0.8,
                 colorbar_x=1.15, colorbar_title='Spundbohle 2',
                 colorbar_thickness=20, colorbar_len=0.5,
                 autocolorscale=False,
                 colorscale=[[0, 'rgb(7,64,80)'],
                             [0.5, 'rgb(255,255,255)'],
                             [1, 'rgb(34,139,34)']],
                 cmin=eps_min, cmax=eps_max, cmid=0
                 ),
      #Tracé de l'axe neutre de la palplanche 2
      go.Scatter3d(x=axe_n[1][0], y=axe_n[1][1], z=axe_n[1][2],
                   name='Neutral Achse - Spundbohle 2',
                   mode='lines', line=dict(color='rgb(218,165,32)', width=3,
                                           dash="longdash")
                  ),
      ])

  #Profil de la section
  fig.add_traces(go.Scatter3d(x=df_char['x'], y=df_char['y'], z=[0]*8,
                   name='Spundbohle Profil',
                   mode='lines',
                   line=dict(color='rgb(112,128,144)', width=5)
                   )
                )
  #Valeurs expérimentales
  fig.add_traces(go.Scatter3d(x=df_char['x'], y=df_char['y'], z=df_char['eps'],
                  name='Experimentelle Messungen',
                  mode='markers', marker_symbol='x',
                  marker_size=3, marker_color='#17BECF'
                  )
                 )

  fig.update_layout(scene = dict(zaxis_title='Dehnungen [μm/m]'),
                    height=800,
                    width=1000,
                    title_text='Experimentelle Dehnungen und ' + \
                                'Interpolation nach dem Verhaltensmodell 2EB',
                    template='plotly_white'
                    )

  #Section a l'echelle 1:1
  fig.update_layout(scene_aspectmode='manual',
                    scene_aspectratio=dict(x=2.16, y=1, z=1),
                    )
  #Affichage des coefficients de correlation
  fig.update_scenes(annotations=[
        dict(
            showarrow=False,
            x=-300,
            y=300,
            z=eps_max,
            text="R^2 = " + str(round(coef_reg[0][3], 4)),
            align="right",
            font_color='rgb(154,205,50)',
            xanchor="left",
            ),
        dict(
            showarrow=False,
            x=300,
            y=300,
            z=eps_max,
            text="R^2 = " + str(round(coef_reg[1][3], 4)),
            font_color='rgb(34,139,34)',
            xanchor="left",
            )
        ]
        )

  return fig

# %%
def _representation_DB(coef_reg, df_char):
  assert type(coef_reg) is tuple, 'Entrée doit être tuple de taille 4'
  assert len(coef_reg) == 4, 'Vérifier le modèle utilisé (DB ou 2EB)'

  c = coef_reg

  x = np.linspace(-700, 700, 10)
  y = np.linspace(-300, 300, 10)
  xGrid, yGrid = np.meshgrid(x, y)
  z = c[0]*xGrid + c[1]*yGrid + c[2]
  eps_max = np.amax(z)

  axe_n = axe_neutre(c, -700, 700)

  df_char = df_char.sort_values('pos_dms')

  fig = go.Figure(data=[
      #Tracé du plan des def
      go.Surface(x=xGrid, y=yGrid, z=z,
                 opacity = 0.8,
                 colorbar_thickness=20, colorbar_len=0.5,
                 colorscale=[[0, 'rgb(7,64,80)'],
                             [0.5, 'rgb(255,255,255)'],
                             [1, 'rgb(154,205,50)']],
                 name='Interpolation d',
                 text=[str(c[3])]
                 ),
      #Tracé de l'axe neutre
      go.Scatter3d(x=axe_n[0], y=axe_n[1], z=axe_n[2],
                   name='Neutral Achse',
                   mode='lines', line=dict(color='rgb(218,165,32)', width=3,
                                           dash="longdash")
                   )
      ])

  #Profil de la section
  fig.add_traces(go.Scatter3d(x=df_char['x'], y=df_char['y'], z=[0]*8,
                   name='Spundbohle Profil',
                   mode='lines',
                   line=dict(color='rgb(112,128,144)', width=5)
                   )
                )
  #Valeurs expérimentales
  fig.add_traces(go.Scatter3d(x=df_char['x'], y=df_char['y'], z=df_char['eps'],
                  name='Experimentelle Messungen',
                  mode='markers', marker_symbol='x',
                  marker_size=3, marker_color='#17BECF'
                  )
                 )

  fig.update_layout(scene = dict(
                    zaxis_title='Dehnungen [μm/m]'),
                    height=800,
                    width=1000,
                    title_text='Experimentelle Dehnungen und ' + \
                                'Interpolation nach dem Verhaltensmodell DB',
                    template='plotly_white'
                    )

  #Section a l'echelle 1:1
  fig.update_layout(scene_aspectmode='manual',
                    scene_aspectratio=dict(x=2.16, y=1, z=1)
                    )
  #Affichage des coefficients de correlation
  fig.update_scenes(annotations=[
        dict(
            showarrow=False,
            x=-600,
            y=300,
            z=eps_max,
            text="R^2 = " + str(round(coef_reg[3], 4)),
            align="right",
            font_color='rgb(154,205,50)',
            xanchor="left",
            ),
        ]
        )
  return fig

# %%
def _representation_interp(df_char):

  if len(df_char) != 8:
    print("Erreur : Interpolation uniquement pour des données de chargement")
    return False

  df_char = df_char.sort_values('pos_dms')

  coef_reg = _interpolation_chargement(df_char)

  if len(coef_reg)==2:
    fig = representation_2EB(coef_reg, df_char)

  else:
    fig = _representation_DB(coef_reg, df_char)


  # fig.update_layout(scene_aspectmode='cube')

  fig.update_layout(scene=dict(xaxis_showspikes=False,
                             yaxis_showspikes=False))


  fig.show()

# %% [markdown]
# Fonctions utiles utilisateur :
#
#
# *   projection_chargement()
# *   representation_interp(df_char)

# %% [markdown]
# **Exemples**
# ---

# %%
df_char = projection_chargement(7, 'sch', 138, 1)
_representation_interp(df_char)
# Out:
# (3.1280000000000006, 13.977732793522268, 3269.3898785425104, 0.9512206777042901)
# (2.2006666666666677, 14.819838056680169, -3149.1635627530372, 0.9397435875192428)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="454a7574-d98f-4d75-9019-10a71fdc5149" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("454a7574-d98f-4d75-9019-10a71fdc5149")) {
#                     Plotly.newPlot(
#                         '454a7574-d98f-4d75-9019-10a71fdc5149',
#                         [{"autocolorscale": false, "cmax": 4979.963157894737, "cmid": 0, "cmin": -4851.214035087721, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[-31 ...

# %%
df_char = projection_chargement(15, 'klebt', 120, 1)
_representation_interp(df_char)
# Out:
# (-7.093333333333335, 18.414979757085025, 1590.3704453441296, 0.9311502560616408)
# (-0.22666666666666682, 5.072874493927126, -751.3967611336033, 0.9947106219641895)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="62f83656-1a37-4126-8a4e-2c7ea64bd630" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("62f83656-1a37-4126-8a4e-2c7ea64bd630")) {
#                     Plotly.newPlot(
#                         '62f83656-1a37-4126-8a4e-2c7ea64bd630',
#                         [{"autocolorscale": false, "cmax": 8397.201754385966, "cmid": 0, "cmin": -4643.4568151147105, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[10 ...

# %%
df_char = projection_chargement(7.5, 'klebt', 58, 1)
_representation_interp(df_char)
# Out:
# (0.02400000000000006, 3.429149797570851, 480.7587044534414, 0.9986633245140215)
# (0.029333333333332903, 3.6902834008097174, -516.1137651821862, 0.9848953047969486)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="127e69ae-49fa-4351-a5ee-684f8529d4be" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("127e69ae-49fa-4351-a5ee-684f8529d4be")) {
#                     Plotly.newPlot(
#                         '127e69ae-49fa-4351-a5ee-684f8529d4be',
#                         [{"autocolorscale": false, "cmax": 826.0736842105266, "cmid": 0, "cmin": -888.0754385964913, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[-56 ...

# %% [markdown]
# *Comportement 2EB*

# %%
df_char = projection_chargement(0.3, 'sch', 22, 1)
_representation_interp(df_char)
# Out:
# (0.056000000000000105, 1.7368421052631586, 259.58947368421065, 0.9997380881517357)
# (0.005999999999999955, 1.9595141700404866, -274.1906882591094, 0.9920517826213999)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="705a3ba9-6612-4c26-aecd-08da3b8186c2" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("705a3ba9-6612-4c26-aecd-08da3b8186c2")) {
#                     Plotly.newPlot(
#                         '705a3ba9-6612-4c26-aecd-08da3b8186c2',
#                         [{"autocolorscale": false, "cmax": 438.87368421052656, "cmid": 0, "cmin": -470.742105263158, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[-30 ...

# %% [markdown]
# *Comportement DB*

# %%
df_charEB = projection_chargement(15, 'klebt', 29, 1)
_representation_interp(df_charEB)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b87737e9-4147-4c45-b3ab-8b3ec82eba5c" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b87737e9-4147-4c45-b3ab-8b3ec82eba5c")) {
#                     Plotly.newPlot(
#                         'b87737e9-4147-4c45-b3ab-8b3ec82eba5c',
#                         [{"colorbar": {"len": 0.5, "thickness": 20}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation d", "opacity": 0.8, "text": ["0.9925813033952894"], "type": "surface", "x": [[-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0], [-700.0, -544.4444444444445, -388.8888888888889, -233.33333333333337, -77.77777777777783, 77.77777777777771, 233.33333333333326, 388.8888888888887, 544.4444444444443, 700.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331, -233.33333333333331], [-166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666, -166.66666666666666], [-100.0, -100.0, -100.0, -100.0, -100.0, -100.0, -100.0, -100.0, -100.0, -100.0], [-33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314, -33.333333333333314], [33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337, 33.33333333333337], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], [166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669, 166.66666666666669], [233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337, 233.33333333333337], [300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0]], "z": [[-66.61875660136522, -106.36297618330082, -146.10719576523638, -185.851415347172, -225.59563492910758, -265.33985451104314, -305.08407409297877, -344.82829367491433, -384.5725132568499, -424.3167328387856], [-11.820368885792874, -51.56458846772847, -91.30880804966405, -131.05302763159966, -170.79724721353523, -210.54146679547082, -250.28568637740642, -290.029905959342, -329.7741255412776, -369.5183451232132], [42.978018829779415, 3.233 ...
#                         {"height": 800, "scene": {"annotations": [{"align": "right", "font": {"color": "rgb(154,205,50)"}, "showarrow": false, "text": "R^2 = 0.9926", "x": -600, "xanchor": "left", "y": 300, "z": 426.5667328387856}], "aspectmode": "manual", "aspectratio": {"x": 2.16, "y": 1, "z": 1}, "xaxis": {"showspikes": false}, "yaxis": {"showspikes": false}, "zaxis": {"title": {"text": "Dehnung

# %% [markdown]
# *Comportement DB et interpolation 2EB*

# %%
c = interpolation_2EB(df_charEB)
representation_2EB(c, df_charEB)
# Out:
# (-0.21133333333333326, 0.862348178137652, 20.128340080971697, 0.9982689051410455)
# (-0.28200000000000003, 0.8036437246963564, 9.28016194331984, 0.9999371714042627)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc68d37c-ee3e-4ce6-9ea3-997afa16b7c9" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc68d37c-ee3e-4ce6-9ea3-997afa16b7c9")) {
#                     Plotly.newPlot(
#                         'dc68d37c-ee3e-4ce6-9ea3-997afa16b7c9',
#                         [{"autocolorscale": false, "cmax": 278.5732793522268, "cmid": 0, "cmin": -268.4842105263158, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[-90 ...

# %% [markdown]
# *Comportement 2EB avec apparition de déformations plastiques : une asymétrie dans la répartition des déformations apparaît*

# %%
df_char = projection_chargement(7, 'sch', 47, 1)
_representation_interp(df_char)
# Out:
# (0.5073333333333334, 4.133603238866397, 799.7607287449393, 0.9808904518671051)
# (0.4793333333333334, 4.445344129554656, -803.5024291497976, 0.9715295426710298)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a6aca89-f0a3-4b85-a0e1-0f528fb7b242" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a6aca89-f0a3-4b85-a0e1-0f528fb7b242")) {
#                     Plotly.newPlot(
#                         '4a6aca89-f0a3-4b85-a0e1-0f528fb7b242',
#                         [{"autocolorscale": false, "cmax": 1263.8543859649124, "cmid": 0, "cmin": -1295.9701754385967, "colorbar": {"len": 0.5, "thickness": 20, "title": {"text": "Spundbohle 1"}, "x": 1}, "colorscale": [[0, "rgb(7,64,80)"], [0.5, "rgb(255,255,255)"], [1, "rgb(154,205,50)"]], "name": "Interpolation - Spundbohle 1", "opacity": 0.8, "type": "surface", "x": [[-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0], [-700.0, -611.1111111111111, -522.2222222222222, -433.33333333333337, -344.44444444444446, -255.55555555555554, -166.66666666666674, -77.77777777777783, 11.111111111111086, 100.0]], "y": [[-300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0, -300.0], [-255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554, -255.55555555555554], [-211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111, -211.11111111111111], [-166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669, -166.66666666666669], [-122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223, -122.22222222222223], [-77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777, -77.77777777777777], [-33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337, -33.33333333333337], [11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086, 11.111111111111086], [55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554, 55.55555555555554], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]], "z": [[- ...

# %% [markdown]
# # Axe neutre : Synthèse

# %% [markdown]
# *Objectif : Construire un graphique permettant de distinguer le comportement local des palplanches.*
#
#
# Pour ce faire, on choisit de répérer la position de l'axe neutre en fonction de son orientation pour chacun des chargements. En comparant la répartition des points avec les deux comportements limites, 2*EB et DB, on donne un éventail de comportements locaux possibles pour une palplanche double en flexion simple.

# %% [markdown]
# On décide de ne conserver que les chargements pertinents. On ne considérera pas par exemple les chargements initiaux, De plus, on ne travaillera qu'avec les parties élastiques des déformations.

# %% [markdown]
# ## Fonctions utiles

# %%
def param_axe_neutre_palplanche(c, x_centre_pal):

  """
  Renvoie les paramètres géométriques d'une seule regression c
  """

  assert type(c) is tuple, 'Paramètre d entrée est le tuple d une seule régr.'
  assert len(c) == 4, 'Mauvaise entrée'

  if c[1] == 0:
    return 0,0
  else:
    alpha = abs(np.degrees(np.arctan(-c[0]/c[1])))
    hauteur = -c[0]/c[1]*x_centre_pal - c[2]/c[1]
    return alpha, hauteur

# %%
def new_df_param_axes_neutres_elastique(df):
  """
  Construit la base de données des paramètres des axes neutres
  """

  #Par prévention
  df = add_pos_dms(df)

  df_axe_neutre = pd.DataFrame(columns=['serr_long', 'serr_type',
                                        'force', 'charg',
                                        'indice_pal',
                                        'alpha_axe_neutre',
                                        'hauteur_axe_neutre',
                                        'coeff_correlation_axe_neutre'])

  index = 0

  serr_longs = df['serr_long']
  serr_types = df['serr_type']
  forces = df['force']
  charges = df['charg']
  essais = list(zip(serr_longs, serr_types, forces, charges))
  essais = list(set(essais))

  for essai in essais:
    serr_long, serr_type, force, charg = essai
    df_char = projection_chargement(serr_long, serr_type, force, charg)
    if len(df_char) !=0:
      coefs_pal = interpolation_2EB_elastique(df_char)
      for i in [1,2]:
        alpha, hauteur_axe = param_axe_neutre_palplanche(coefs_pal[i-1], 0)

        n_row = pd.DataFrame({
            'serr_long': [serr_long],
            'serr_type': [serr_type],
            'force': [force],
            'charg': [charg],
            'indice_pal': [i],
            'alpha_axe_neutre': [alpha],
            'hauteur_axe_neutre': [hauteur_axe],
            'coeff_correlation_axe_neutre': [coefs_pal[i-1][3]]},
            index=[index])

        df_axe_neutre = pd.concat([df_axe_neutre, n_row])
        index += 1

  return df_axe_neutre

# %%
# df = reset_df()
# df = deformations_elastiques(df)
df_axe_neutre = new_df_param_axes_neutres_elastique(df)

# %% [markdown]
# *Sans le coefficient de corrélation*

# %%
def graphique_angle_hauteur(df_axe_neutre):
  """
  Place les points pour chaque essais sur le plan (angle, hauteur)
  """
  fig = go.Figure()

  serr_longs = df['serr_long']
  serr_types = df['serr_type']
  essais = list(zip(serr_longs, serr_types))
  essais = list(set(essais))
  essais.sort()
  MARKERS = ["circle", "square", "diamond", "octagon",
             "diamond-tall", "star-diamond", "x", "cross"]

  for i in range(len(essais)):
    serr_long, serr_type = essais[i]
    fig.add_traces(go.Scatter(
        x=df_axe_neutre["alpha_axe_neutre"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                (df_axe_neutre["serr_type"] == serr_type) &
                                                (df_axe_neutre["force"] > 10)
                                                ],
        y=df_axe_neutre["hauteur_axe_neutre"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                  (df_axe_neutre["serr_type"] == serr_type) &
                                                  (df_axe_neutre["force"] > 10)
                                                 ],
        mode="markers",
        marker_symbol=MARKERS[i%(len(MARKERS))],
        marker_size=8,
        marker_line_color="DarkSlateGrey",
        marker_line_width=1,
        name="Versuche "+str(serr_long)+"m "+str(serr_type),
        hovertemplate='Winkel: %{x:.1f} ° <br>' +
                      "Ordinatenabschnitt: %{y:.1f} mm <br>" +
                      'Kraft: %{text} kN <br>' +
                      'Zustand: %{customdata}',
        text=df_axe_neutre["force"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                            (df_axe_neutre["serr_type"] == serr_type) &
                                            (df_axe_neutre["force"] > 10)],
        customdata=['Chargement' if i else 'Déchargement' \
                    for i in df_axe_neutre["charg"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                        (df_axe_neutre["serr_type"] == serr_type) &
                                                        (df_axe_neutre["force"] > 10)]],

                            )
                    )

  alpha_max = max(df_axe_neutre["alpha_axe_neutre"].loc[(df_axe_neutre["force"] > 10)])
  alpha = np.linspace(0, 1.20*alpha_max, 100)
  h = np.tan(np.radians(alpha))*300 + 138.1
  h_moins = -np.tan(np.radians(alpha))*300 - 138.1

  fig.add_traces(go.Scatter(x=alpha, y=h, mode='lines',
                            name="Menge neutraler Achsen, die durch <br>die Mitte der Spundbohle verlaufen",
                            legendgroup="group2",
                            opacity=0.6,
                            line=dict(color='#7F7F7F', width=1, dash="dash")
                            )
                )

  fig.add_traces(go.Scatter(x=alpha, y=h_moins, mode='lines',
                            name = "Palplanche 1",
                            legendgroup="group2",
                            opacity=0.4,
                            showlegend=False,
                            line=dict(color='#7F7F7F', width=1, dash="dash")
                            )
                )

  x = np.full(1, 19.34)
  y = np.linspace(0, 0, 1)

  fig.add_traces(go.Scatter(x=x, y=y, mode="markers",
                            marker_symbol=33,
                            marker_line_color="#F08080",
                            marker_size=12,
                            marker_line_width=2,
                            name = "Doppelbohlen - Theorie",
                            hovertemplate='Angle: 19.34° <br>'
                            )
                )

  x = np.array([0 , 0])
  y = np.array([-138.1 , 138.1])

  fig.add_traces(go.Scatter(x=x, y=y, mode="markers",
                          marker_symbol=33,
                          marker_line_color="#000000",
                          marker_size=12,
                          marker_line_width=2,
                          name = "Einzelbohlen - Theorie"
                          )
                )

  fig.update_layout(xaxis_title="Winkel [°]",
                    yaxis_title=r"Ordinatenabschnitt [mm]",
                    hoverlabel_align = 'right',
                    width=1200,
                    height=800,
                    template='plotly_white'
                    )

  fig.show()

# %% [markdown]
# *Avec le coefficient de corrélation*

# %%
#@title
def graphique_angle_hauteur_r2(df_axe_neutre):
  """
  Place les points pour chaque essais sur le plan (angle, hauteur)
  """
  fig = go.Figure()

  serr_longs = df['serr_long']
  serr_types = df['serr_type']
  essais = list(zip(serr_longs, serr_types))
  essais = list(set(essais))
  essais.sort()
  MARKERS = ["circle", "square", "diamond", "octagon",
             "diamond-tall", "star-diamond", "x", "cross"]

  for i in range(len(essais)):
    serr_long, serr_type = essais[i]
    fig.add_traces(go.Scatter(
        x=df_axe_neutre["alpha_axe_neutre"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                (df_axe_neutre["serr_type"] == serr_type) &
                                                (df_axe_neutre["force"] > 10)
                                                ],
        y=df_axe_neutre["hauteur_axe_neutre"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                (df_axe_neutre["serr_type"] == serr_type) &
                                                (df_axe_neutre["force"] > 10)
                                                ],
        mode="markers",
        marker_symbol=MARKERS[i%(len(MARKERS))],
        marker_size=10,
        marker_line_color="DarkSlateGrey",
        marker_line_width=1,
        name="Versuche "+str(serr_long)+"m "+str(serr_type),
        # Visualiser les coeff de correlation
        marker_color=df_axe_neutre['coeff_correlation_axe_neutre'],
        marker=dict(colorscale='Viridis',
                    showscale=bool(i==0),
                    colorbar_len=0.3,
                    colorbar_title='R^2',
                    colorbar_thickness=20,
                    colorbar_y=0.01,
                    colorbar_x=1.05
                   ),
        hovertemplate='Winkel: %{x:.1f} ° <br>' +
                      "Ordinate: %{y:.1f} mm <br>" +
                      'Kraft: %{text} kN <br>' +
                      'Stand: %{customdata}',
        text=df_axe_neutre["force"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                            (df_axe_neutre["serr_type"] == serr_type) &
                                            (df_axe_neutre["force"] > 10)],
        customdata=['Chargement' if i else 'Déchargement' \
                    for i in df_axe_neutre["charg"].loc[(df_axe_neutre["serr_long"] == serr_long) &
                                                        (df_axe_neutre["serr_type"] == serr_type) &
                                                        (df_axe_neutre["force"] > 10)]],
                  )
    )

  alpha_max = max(df_axe_neutre["alpha_axe_neutre"].loc[(df_axe_neutre["force"] > 10)])
  alpha = np.linspace(0, 1.20*alpha_max, 100)
  h = np.tan(np.radians(alpha))*300 + 138.1
  h_moins = -np.tan(np.radians(alpha))*300 - 138.1

  fig.add_traces(go.Scatter(x=alpha, y=h, mode='lines',
                            name="Menge neutraler Achsen, die durch <br>die Mitte der Spundbohle verlaufen",
                            legendgroup="group2",
                            opacity=0.6,
                            line=dict(color='#7F7F7F', width=1, dash="dash")
                            )
                )

  fig.add_traces(go.Scatter(x=alpha, y=h_moins, mode='lines',
                            name = "Spundbohle 1",
                            legendgroup="group2",
                            opacity=0.4,
                            showlegend=False,
                            line=dict(color='#7F7F7F', width=1, dash="dash")
                            )
                )

  x = np.full(1, 19.34)
  y = np.linspace(0, 0, 1)

  fig.add_traces(go.Scatter(x=x, y=y, mode="markers",
                            marker_symbol=33,
                            marker_line_color="#F08080",
                            marker_size=12,
                            marker_line_width=2,
                            name = "DB Theorie"))
  x = np.array([0 , 0])
  y = np.array([-138.1 , 138.1])

  fig.add_traces(go.Scatter(x=x, y=y, mode="markers",
                          marker_symbol=33,
                          marker_line_color="#AAA15A",
                          marker_size=12,
                          marker_line_width=2,
                          name = "EB Theorie"))

  fig.update_layout(xaxis_title="Winkel [°]",
                    yaxis_title=r"Ordinate [mm]",
                    width=1000,
                    height=800,
                    template='plotly_white'
                    )


  fig.show()

# %% [markdown]
# ## Graphiques

# %%
graphique_angle_hauteur(df_axe_neutre)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ffd35b9f-ab33-43ca-a277-4c74acc40b8e" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ffd35b9f-ab33-43ca-a277-4c74acc40b8e")) {
#                     Plotly.newPlot(
#                         'ffd35b9f-ab33-43ca-a277-4c74acc40b8e',
#                         [{"customdata": ["D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "Chargement", "Chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinatenabschnitt: %{y:.1f} mm <br>Kraft: %{text} kN <br>Zustand: %{customdata}", "marker": {"line": {"color": "DarkSlateGrey", "width": 1}, "size": 8, "symbol": "circle"}, "mode": "markers", "name": "Versuche 0.3m sch", "text": [22, 22, 105, 105, 53, 53, 53, 53, 22, 22], "type": "scatter", "x": [8.622803969682357, 8.28096656309804, 3.229962371600452, 1.8256000653687976, 4.171471231757708, 4.113003897046572, 0.4261834209056377, 0.3229646590266472, 1.8467150753891908, 0.17543818154499866], "y": [-209.37149569303057, 199.12380952380954, -163.3753228782288, 150.86440922190204, -173.50090025207055, 167.73495072024264, -141.58007085916742, 139.8130081300813, -149.46060606060607, 139.9278925619835]}, {"customdata": ["Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinatenabschnitt: %{y:.1f} mm <br>Kraft: %{text} kN <br>Zustand: %{customdata}", "marker": {"line": {"color": "DarkSlateGrey", "width": 1}, "size": 8, "symbol": "square"}, "mode": "markers", "name": "Versuche 0.8m sch", "text": [52, 52, 22, 22, 114, 114, 52, 52, 21, 21], "type": "scatter", "x": [0.1924460896839706, 0.9770885978159036, 3.598279178975861, 4.712042767218387, 1.9082252890228744, 0.36164667193434086, 1.8146985807725515, 2.3928867126939837, 0.6674591404800675, 1.0149379558485423], "y": [-137.83834778174403, 142.62402900051788, -170.93228346456692, 164.97032842582104, -151.21234812794447, 139.25050505050504, -155.11967213114755, 151.90198113207546, -141.79292517006803, 143.43889655172416]}, {"customdata": ["Chargement", "Chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinatenabschnitt: %{y:.1f} mm <br>Kraft: %{text} kN <br>Zustand: %{customdata}", "marker": {"line": {"color": "DarkSlateGrey", "width": 1}, "size": 8, "symbol": "diamond"}, "mode": "markers", "name": "Versuche 1.3m sch", "text": [22, 22, 53, 53, 53, 53, 119, 119, 22, 22], "type": "scatter", "x": [0.566630476994029, 2.288758769932334, 0.19254427572538693, 0.8568652569691212, 0.683453778367807, 1.7807127145453843, 1.2545304681476968, 0.2500867466884253, 0.497119748932331, 4.690447721339718], "y": [-141.1831831831832, 149.46116504854368, -140.2047027506655, 141.85962230215827, -144.88638239339753, 148.83118926422952, -146.15024390243903, 138.56283783783783, -139.49782359679267, 165.18192352259564]}, {"customdata": ["D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "Chargement", "Chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinatenabschnitt: %{y:.1f} mm <br>Kraft: %{text} kN <br>Zustand: %{customdata}", "marker": {"line": {"color": "DarkSlateGrey", "width": 1}, "size": 8, "symbol": "octagon"}, "mode": "markers", "name": "Versuche 2.0m klebt", "text": [56, 56, 95, 95, 21, 21, 56, 56, 22, 22], "type": "scatter", "x": [3.786381323655715, 1.4373677268451486, 2.6452848025974496, 0.2925019916200902, 0.9284661403217686, 1.5901166149338037, 1.3275298049979054, 0.08552700753678406, 8.776266512830649, 3.104568433047146], "y": [-170.64623955431753, 144.07809523809524, -159.8016889131027, 137.5665045592705, -143.91107205623902, 145.31647509578545, -145.61521739130436, 136.38787535410765, -210.7057167985928, 151.77865612648222]}, {"customdata": ["Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement"], "hovertemplate": "Winkel: %{x:.1 ...

# %%
graphique_angle_hauteur_r2(df_axe_neutre)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c03ba689-bfa0-48b5-ae9d-cb79d4cf26f3" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c03ba689-bfa0-48b5-ae9d-cb79d4cf26f3")) {
#                     Plotly.newPlot(
#                         'c03ba689-bfa0-48b5-ae9d-cb79d4cf26f3',
#                         [{"customdata": ["D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "Chargement", "Chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinate: %{y:.1f} mm <br>Kraft: %{text} kN <br>Stand: %{customdata}", "marker": {"color": [0.9934721077049927, 0.9467866806312282, 1.0, 1.0, 0.9887338971733115, 0.9555709393253171, 0.9284794730509974, 0.9488403987608786, 1.0, 1.0, 0.9941389290882778, 0.9789156975434576, 0.8046398046398047, 0.47368421052631576, 1.0, 1.0, 0.977508038487488, 0.9654061404950568, 0.9994152701802606, 0.9894789885938876, 0.9986979035955971, 0.9892070524143008, 0.9952319048813678, 0.9788059485800295, 0.9951368829435628, 0.9956392467789891, 1.0, 1.0, 0.9971778396391805, 0.9970493616387909, 0.9992977095049418, 0.9625191380476008, 0.9982689051410455, 0.9999371714042627, 0.9996155113586006, 0.9879310303150435, 0.999189327952873, 0.9540808217272962, 0.9998878004923459, 0.9969654788085941, 1.0, 0.9735815098087593, 1.0, 1.0, 0.9999933395497536, 0.9979409736273632, 0.9996032851546331, 0.9882858062357406, 0.9889342866870957, 0.9631620410641895, 0.9892580814440207, 0.9585835794528303, 0.9517027737548095, 0.9324020444988376, 0.9993344858404275, 0.9636535719743793, 0.9995469250830781, 0.9698992276592662, 0.9999627486249166, 0.9892310543272845, 0.9973161441413241, 0.9888063027012135, 0.8998957485932222, 0.9597845997434252, 1.0, 1.0, 0.99988720014595, 0.9911920132178088, 0.998126172297287, 0.9751288236721528, 0.9996864016383915, 0.9953376575118944, 0.9997705323743736, 0.9790874051970658, 0.999608660512995, 0.9754401899596465, 0.8754671281284226, 0.9794282682845574, 0.9995074023270261, 0.9748982009832627, 0.8855630941356566, 0.8930674121062251, 0.9009084445848804, 0.9948559670781894, 0.9993375460510188, 0.9631642524887768, 0.9999341117088074, 0.9909561145859919, 0.9819814259211807, 0.9805351487057389, 0.9999180393393448, 0.997024355947706, 0.9281015147790237, 0.7282595134123518, 1.0, 0.9875688906116494, 0.9999868337174829, 0.9901260215325497, 0.9995351604946789, 0.9959721379158941, 0.9993321250695703, 0.9751821415313336, 0.9311502560616408, 0.9947106219641895, 0.9997380881517357, 0.9920517826213999, 1.0, 1.0, 0.9568210461728122, 0.9267789292671523, 0.999997699814789, 0.9842008392336565, 0.9999793659381777, 0.9892924169685244, 0.9996454286654664, 0.9774106510573071, 0.9401752330212431, 0.9447440723255245, 1.0, 1.0, 0.9745385105028644, 0.7784615384615385], "colorbar": {"len": 0.3, "thickness": 20, "title": {"text": "R^2"}, "x": 1.05, "y": 0.01}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "line": {"color": "DarkSlateGrey", "width": 1}, "showscale": true, "size": 10, "symbol": "circle"}, "mode": "markers", "name": "Versuche 0.3m sch", "text": [22, 22, 105, 105, 53, 53, 53, 53, 22, 22], "type": "scatter", "x": [8.622803969682357, 8.28096656309804, 3.229962371600452, 1.8256000653687976, 4.171471231757708, 4.113003897046572, 0.4261834209056377, 0.3229646590266472, 1.8467150753891908, 0.17543818154499866], "y": [-209.37149569303057, 199.12380952380954, -163.3753228782288, 150.86440922190204, -173.50090025207055, 167.73495072024264, -141.58007085916742, 139.8130081300813, -149.46060606060607, 139.9278925619835]}, {"customdata": ["Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement", "D\u00e9chargement", "D\u00e9chargement", "Chargement", "Chargement"], "hovertemplate": "Winkel: %{x:.1f} \u00b0 <br>Ordinate: %{y:.1f} mm <br>Kraft: %{text} kN <br>Stand: %{customdata}", "marker": {"color": [0.9934721077049927, 0.9467866806312282, 1.0, 1.0, 0.9887338971733115, 0.9555709393253171, 0.9284794730509974, 0.948840398760878 ...

# %% [markdown]
# Remarque : pour certains essais (en particulier, (1.3, sch), (0.8, sch), (7.5, klbet), on voit apparaître une véritable dissymétrie entre les deux palplanches.

# %% [markdown]
# En l'état (et en choisisant la hauteur en x=0), on distingue 4 cas de comportement:
# *   alpha = 0, h = 139 --> comportement strictement EB
# *   Sur les pointillés : l'axe neutre de la palplanche est, au niveau de l'abscisse x=300 (ie milieu de la palplanche), a la hauteur théorique. On voit seulement apparaître un déséquilibre des efforts au niveau de la serrure (la courbe théorique croissante de alpha)
# *   Comportement DB : pour les essais (serr_long, serr_type) = (15, klebt)
